# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
    print(f"Ajouté au path : {PROJECT_ROOT}")

# %%
from utils.utils import load_config
from utils.eda_utils import show_image_pair, sample_random_pairs
from utils.data_utils import get_pairs_dataframe

CONFIG = load_config('../config/dataset.yml')
df_pairs = get_pairs_dataframe(CONFIG, PROJECT_ROOT, categories="ALL")

# %%
pair = sample_random_pairs(df_pairs, CONFIG)

# %%
pair

# %%
show_image_pair(pair[0], pair[1])
