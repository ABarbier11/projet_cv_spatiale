# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
    print(f"Ajouté au path : {PROJECT_ROOT}")

# %%
from utils.utils import load_config
from utils.data_utils import get_pairs_dataframe
from utils.eda_utils import plot_image_gallery

# %%
config_path = PROJECT_ROOT / "config" / "dataset.yml"
CONFIG = load_config(config_path)

print("Chargement du dataset complet...")
df_all = get_pairs_dataframe(CONFIG, PROJECT_ROOT, categories="ALL")
print(f"Images chargées : {len(df_all)}")

# %%
# Objectif : Détecter les nuages, les bords noirs, les aberrations.
print("\n--- 1. Vue d'ensemble aléatoire ---")
plot_image_gallery(df_all, CONFIG, n_rows=3, n_cols=3)

# %%
# Objectif : Voir si les champs sont verts (été) ou nus (hiver),
# et comment le SAR réagit (texture unie vs bruitée).
print("\n--- 2. Focus : AGRICULTURE ---")
df_agri = df_all[df_all[CONFIG['columns']['category']] == 'agri']
plot_image_gallery(df_agri, CONFIG, n_rows=2, n_cols=3)

# %%
# Objectif : Voir comment les bâtiments apparaissent en SAR (points brillants).
print("\n--- 3. Focus : URBAIN ---")
df_urban = df_all[df_all[CONFIG['columns']['category']] == 'urban']
plot_image_gallery(df_urban, CONFIG, n_rows=2, n_cols=3)
